# %%
import matplotlib as mp
import pandas as pd

dfSueldos = pd.read_csv('../csv/sueldos.csv')
dfViajes = pd.read_csv('../csv/viajes.csv')

print(dfViajes['TIPO_TRANSPORTE'].value_counts().plot.bar(rot=0))
dfSueldos['TOTAL SALARIO BRUTO'] = [float(i[1:].replace(',', '.')) for i in dfSueldos['TOTAL SALARIO BRUTO']]

#pregunta: Por qué el valor de i no se modifica antes del print(i + " after ")?
#dfSueldos['TOTAL SALARIO BRUTO'] = [(print(i + " before "), i[1:], print(i + " after")) for i in dfSueldos['TOTAL SALARIO BRUTO']]

print(dfSueldos['TOTAL SALARIO BRUTO'])
print(dfSueldos.plot.bar(x='APELLIDO_Y_NOMBRE', y='TOTAL SALARIO BRUTO', rot=0))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 0      245.812
# 1      245.812
# 2      245.812
# 3      245.812
# 4      245.812
#         ...
# 247    283.458
# 248    283.458
# 249    283.458
# 250    283.458
# 251    425.187
# Name: TOTAL SALARIO BRUTO, Length: 252, dtype: float64
# AxesSubplot(0.125,0.125;0.775x0.755)
