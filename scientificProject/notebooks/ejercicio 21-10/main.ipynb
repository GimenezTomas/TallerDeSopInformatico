# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as grafico

dfTemperaturas = pd.read_csv("../csv/historico_temperaturas.csv", sep=",", engine="python")
mediaMax = dfTemperaturas.iloc[dfTemperaturas["media"].idxmax()]
mediaMin = dfTemperaturas.iloc[dfTemperaturas["media"].idxmin()]
print("La maxima media (",mediaMax.loc['media'],") fue en ",mediaMax.loc['mes']," del ",mediaMax.loc["año"])
print("La minima media (",mediaMin.loc['media'],") fue en ",mediaMin.loc['mes']," del ",mediaMin.loc["año"])


data = pd.read_csv("../csv/historico_temperaturas.csv",sep=",",engine="python")
data1 = data[["media","año", "mes"]]
grafico = sb.pairplot(data1,hue="mes",palette="icefire")
# Out:
# La maxima media ( 27.0 ) fue en  Diciembre  del  2013
# La minima media ( 8.95 ) fue en  Julio  del  1992
